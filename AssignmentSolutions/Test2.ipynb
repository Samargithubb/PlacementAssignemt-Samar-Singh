# %% [markdown]
# #### 1.You are given two non-empty linked lists representing two non-negative integers. The digits are stored in reverse order, and each of their nodes contains a single digit. Add the two numbers and return the sum as a linked list.
#
# You may assume the two numbers do not contain any leading zero, except the number 0 itself.
#
#
# Example 1:
#
# Input: l1 = [2,4,3], l2 = [5,6,4] Output: [7,0,8] Explanation: 342 + 465 = 807.
#
# Example 2:
#
# Input: l1 = [0], l2 = [0] Output: [0]
#
# Example 3:
#
# Input: l1 = [9,9,9,9,9,9,9], l2 = [9,9,9,9] Output: [8,9,9,9,0,0,0,1]
#
#
#
# Constraints:
#
# The number of nodes in each linked list is in the range [1, 100].
# 0 <= Node.val <= 9 It is guaranteed that the list represents a number that does not have leading zeros.

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def addTwoNumbers(l1, l2):
    dummy = ListNode()
    current = dummy
    carry = 0

    while l1 or l2:
        sum_val = carry

        if l1:
            sum_val += l1.val
            l1 = l1.next
        if l2:
            sum_val += l2.val
            l2 = l2.next

        carry = sum_val // 10
        current.next = ListNode(sum_val % 10)
        current = current.next

    if carry:
        current.next = ListNode(carry)

    return dummy.next

l1 = ListNode(2)
l1.next = ListNode(4)
l1.next.next = ListNode(3)

l2 = ListNode(5)
l2.next = ListNode(6)
l2.next.next = ListNode(4)

result = addTwoNumbers(l1, l2)

while result:
    print(result.val, end=" ")
    result = result.next
# Out:
# 7 0 8

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 28BF-16EF
#
#  Directory of C:\Users\samar
#
# 18-06-2023  20:22    <DIR>          .
# 23-12-2022  21:37    <DIR>          ..
# 26-10-2022  19:29         3,462,670  Admission Prediction project .ipynb
# 05-07-2022  16:05    <DIR>          .anaconda
# 25-04-2023  14:59    <DIR>          .astra
# 08-06-2022  15:31    <DIR>          .astropy
# 18-04-2023  15:24               122 .bash_history
# 28-09-2022  17:45    <DIR>          .cassandra
# 23-05-2023  17:05    <DIR>          .conda
# 26-11-2021  11:14                25 .condarc
# 26-11-2021  11:14    <DIR>          .continuum
# 13-09-2022  08:01    <DIR>          .cufflinks
# 16-03-2023  18:49    <DIR>          .docker
# 16-05-2023  19:39               211 .gitconfig
# 19-11-2021  17:58    <DIR>          .idlerc
# 18-06-2023  20:18    <DIR>          .ipynb_checkpoints
# 26-11-2021  11:17    <DIR>          .ipython
# 26-11-2021  12:11    <DIR>          .jupyter
# 22-03-2023  05:17    <DIR>          .keras
# 22-04-2023  18:15             1,096 .labelImgSettings.pkl
# 16-03-2023  09:04                20 .lesshst
# 23-12-2022  21:03    <DIR>          .matplotlib
# 25-01-2023  20:19    <DIR>          .vscode
# 04-05-2023  13:23    <DIR>          .vscode-cli
# 28-11-2022  18:25    <DIR>          .wdm
# 01-08-2022  05:46             9,080 01.Assignment_1.ipynb
# 22-10-2022  13:13             5,012 01.Python_Assignment.ipynb
# 08-08-2022  18:28             7,288 02.Assignment_02.ipynb
# 23-10-2022  15:57             8,584 02.Python_Assignement.ipynb
# 08-08-2022  19:16             9,864 03.Assignment_3.ipynb
# 23-10-2022  17:03             6,760 03.Python_Assignment.ipynb
# 12-08-2022  18:32             6,936 04.Assignment_4.ipynb
# 24-10-2022  09:39             2,197 04.Python_Assignment .ipynb
# 13-08-2022  09:32             8,190 05.Assignment_5.ipynb
# 13-08-2022  12:37            10,753 06.Assignment_6.ipynb
# 13-08-2022  13:23             9,253 07.Assignment_7.ipynb
# 13-08-2022  16:26             9,782 08.Assignment_8.ipynb
# 15-08-2022  19:42             1,201 09.Assignment_09.ipynb
# 25-05-2021  15:09    <DIR>          3D Objects
# 26-10-2022  18:50               589 admission_lr_model.pickle
# 20-10-2022  18:18            36,906 Advertising data set ML.ipynb
# 14-05-2022  18:01            16,384 airline.xls
# 03-10-2022  16:07        16,415,525 all_data.csv
# 22-04-2023  11:33    <DIR>          anaconda3
# 14-05-2022  17:45            16,384 andy.xls
# 24-03-2023  05:10    <DIR>          ANN
# 22-03-2023  16:09            94,713 ANN Tensorflow.ipynb
# 13-06-2022  16:09    <DIR>          bank
# 17-05-2022  20:10           461,474 bank.csv
# 21-08-2022  20:08    <DIR>          Basic python assignment
# 11-03-2023  19:13    <DIR>          Big mart prediction
# 15-03-2023  08:25           119,621 Black Friday Sale Analysis.ipynb
# 30-05-2022  18:57               207 books.csv
# 31-05-2022  16:08             8,192 books.db
# 17-04-2022  12:07            51,867 car.data
# 02-10-2022  08:21             2,057 CASSANDRA .ipynb
# 27-04-2023  12:58                 0 cd
# 25-02-2023  09:19    <DIR>          cementStrengthPrediction
# 09-10-2022  19:16    <DIR>          Contacts
# 09-06-2023  06:50    <DIR>          Customer Pesonality Analysis Project
# 14-04-2023  08:18             5,970 CustomerPredictionAnalysis EDA.ipynb
# 27-05-2023  08:36    <DIR>          CV Assignments
# 03-05-2022  18:28             1,803 data1.txt
# 30-04-2022  18:27            12,288 database
# 30-04-2022  18:36            12,824 database-journal
# 03-12-2022  18:42        11,274,823 Decision Tree.ipynb
# 28-08-2022  11:52             1,890 df1.ipynb
# 25-03-2023  11:07    <DIR>          Documents
# 16-06-2023  23:30    <DIR>          Downloads
# 30-03-2023  09:17            86,326 Droout for ANN.ipynb
# 15-06-2023  14:28    <DIR>          DSA Assignments
# 04-06-2023  07:39            28,567 EDA cement strength.ipynb
# 30-03-2023  14:43                83 environment.yml
# 10-05-2023  09:08           553,716 exersise.ipynb
# 09-10-2022  19:16    <DIR>          Favorites
# 28-04-2022  16:06               361 file.log
# 14-09-2022  09:43    <DIR>          FitBit (3)
# 16-04-2022  17:27            11,903 glass.data
# 23-03-2022  08:51         1,864,145 image.png.png
# 25-03-2023  11:01            98,859 IncomePrediction.ipynb
# 15-05-2022  15:02             5,905 json2.csv
# 20-10-2022  15:46               496 linear_reg.sav
# 09-10-2022  19:16    <DIR>          Links
# 05-04-2022  13:31             7,478 list.log
# 05-04-2022  11:47             1,979 list1.log
# 12-03-2023  07:37    <DIR>          loan Prediction
# 20-02-2023  08:06         8,515,313 Logistic Regression.ipynb
# 12-05-2022  16:45            12,081 love.docx
# 14-05-2022  17:46           161,651 lucid Excel.xlsx
# 14-05-2022  17:43           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 15-06-2023  16:31    <DIR>          Machine Learning Assignments
# 23-04-2023  07:36    <DIR>          Machine Learning Projects
# 25-01-2023  20:22                 0 main.py
# 27-04-2023  12:58                 0 Microsoft
# 17-12-2022  13:04    <DIR>          ML
# 09-10-2022  19:16    <DIR>          Music
# 30-04-2022  17:13             8,192 mydb
# 30-08-2022  15:04           216,914 My_pickle
# 15-05-2022  08:14                 0 nanotube_logfile.log
# 15-05-2022  13:52            78,961 NBA.csv
# 24-03-2023  04:54    <DIR>          New folder
# 18-05-2022  17:17            62,639 new_size.png
# 11-05-2022  19:55    <DIR>          old folder
# 18-06-2023  20:16    <DIR>          OneDrive
# 30-03-2023  14:20                38 packages.txt
# 03-09-2022  18:05           135,777 Pandas data manipulation .ipynb
# 02-09-2022  18:48    <DIR>          Pandas-main
# 26-05-2022  18:51           481,579 pandas.ipynb
# 15-05-2022  16:47    <DIR>          Pandas_task
# 15-05-2022  17:47         2,822,239 Pandas_task.zip
# 15-12-2022  11:25            26,074 PCA.ipynb
# 31-05-2022  18:09                 0 ping
# 15-09-2022  18:33        19,822,777 plotly matplotlib seaborn cufflinks.ipynb
# 31-07-2022  11:30    <DIR>          png
# 05-07-2022  17:01    <DIR>          Postman
# 30-03-2023  17:00             6,609 practice.ipynb
# 02-03-2023  14:55             3,530 practicess.ipynb
# 27-04-2023  12:58                 0 Program
# 16-06-2023  23:33    <DIR>          project1
# 23-05-2023  18:53    <DIR>          project2
# 15-06-2023  08:15    <DIR>          PycharmProjects
# 16-10-2022  11:05    <DIR>          Python Assignmetn
# 05-03-2023  14:09         6,494,249 Python_Notes.ipynb
# 30-03-2023  14:28             1,501 requirements.txt
# 11-05-2022  20:02            16,471 SalesReport1.csv
# 15-05-2022  17:09         1,595,953 Sales_April_2019.csv
# 15-05-2022  17:47    <DIR>          Sales_Data
# 11-04-2022  16:36         3,937,549 samar.ipynb
# 11-05-2022  19:57               221 sample_test.csv
# 09-10-2022  19:16    <DIR>          Saved Games
# 25-06-2022  17:34    <DIR>          seaborn-data
# 09-10-2022  19:16    <DIR>          Searches
# 26-08-2022  17:09           167,139 Statistics Notes.ipynb
# 09-08-2022  20:25    <DIR>          T-test-an-Correlation-using-python-master
# 15-05-2022  09:05             3,987 Task.ipynb
# 28-11-2022  20:23               173 tee.txt
# 22-08-2022  20:39             1,487 test.csv
# 30-08-2022  15:03                96 test.H5
# 11-08-2022  14:38            12,723 test.log
# 30-05-2022  18:42                43 test.txt
# 18-06-2023  20:18             1,230 Test1.ipynb
# 24-04-2022  11:05             1,803 test1.log
# 18-06-2023  20:22             2,917 Test2.ipynb
# 11-08-2022  12:51                16 test2.txt
# 24-04-2022  12:39             4,670 test22.log
# 11-08-2022  12:07                10 test4.txt
# 15-04-2023  09:07    <DIR>          tf01.x
# 18-04-2023  15:06    <DIR>          tfod2.x
# 12-03-2023  08:55            63,820 The Boston Housing Dataset.ipynb
# 31-05-2022  18:28                10 today.txt
# 18-03-2022  18:51    <DIR>          Tracing
# 26-05-2023  12:30    <DIR>          Untitled Folder
# 09-04-2023  12:05    <DIR>          Untitled Folder 1
# 09-04-2023  12:06    <DIR>          Untitled Folder 2
# 18-10-2022  20:55         3,878,159 Untitled.ipynb
# 05-12-2022  17:52                72 Untitled1.ipynb
# 15-03-2023  17:19            64,356 Untitled2.ipynb
# 23-03-2023  13:26             1,415 Untitled3.ipynb
# 14-04-2023  17:55        17,918,201 Untitled4.ipynb
# 09-10-2022  19:16    <DIR>          Videos
# 08-06-2022  15:28    <DIR>          webscrappper_text-master
# 08-06-2022  15:11         4,969,669 webscrappper_text-master.zip
# 21-06-2022  19:12                46 w_file.txt
# 15-09-2022  19:56       574,072,999 zomato.csv
# 27-05-2022  20:31                47 zoo.py
# 14-12-2022  05:52               204 _netrc
# 27-05-2022  20:31    <DIR>          __pycache__
#              102 File(s)    680,479,399 bytes
#               65 Dir(s)  253,698,392,064 bytes free
